# %% [markdown]
# **EXPERIMENT 2 MULTIMODAL**

# %%
# =========================================================
# MULTIMODAL CLIP
# IMAGE + CAPTION
# TRAINED FOR 6 CLASSES
# REPORTS TASK A + TASK B
# =========================================================

# !pip install -q transformers datasets torchvision scikit-learn

# =========================================================
# GOOGLE DRIVE
# =========================================================
from google.colab import drive

drive.mount('/content/drive')

# =========================================================
# IMPORTS
# =========================================================
import os
import random
import numpy as np

from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

import seaborn as sns

import torch

import torch.nn as nn

from torch.utils.data import Dataset, DataLoader

from datasets import load_dataset

from transformers import (
    CLIPProcessor,
    CLIPModel
)

from torchvision import transforms

from sklearn.preprocessing import label_binarize

from sklearn.metrics import (

    accuracy_score,

    f1_score,

    classification_report,

    roc_curve,

    auc,

    precision_recall_curve,

    average_precision_score
)

from tqdm import tqdm

# =========================================================
# GLOBAL SEED
# =========================================================
SEED = 42

random.seed(SEED)

np.random.seed(SEED)

torch.manual_seed(SEED)

torch.cuda.manual_seed(SEED)

torch.cuda.manual_seed_all(SEED)

os.environ["PYTHONHASHSEED"] = str(SEED)

torch.backends.cudnn.deterministic = True

torch.backends.cudnn.benchmark = False

torch.use_deterministic_algorithms(True)

# =========================================================
# DEVICE
# =========================================================
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("🚀 Device:", device)

# =========================================================
# LOAD DATASET
# =========================================================
dataset = load_dataset(
    "Rajarshi-Roy-research/Defactify_Image_Dataset"
)

train_ds = dataset["train"]

val_ds   = dataset["validation"]

test_ds  = dataset["test"]

# =========================================================
# PROCESSOR
# =========================================================
processor = CLIPProcessor.from_pretrained(
    "openai/clip-vit-base-patch32"
)

# =========================================================
# AUGMENTATION
# =========================================================
train_transform = transforms.Compose([

    transforms.RandomResizedCrop(
        224,
        scale=(0.75, 1.0)
    ),

    transforms.RandomHorizontalFlip(),

    transforms.RandomRotation(10),

    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.2
    ),

    transforms.RandomGrayscale(p=0.05),
])

# =========================================================
# DATASET
# =========================================================
class MultiModalDataset(Dataset):

    def __init__(self, hf_dataset, train=False):

        self.dataset = hf_dataset

        self.train = train

    def __len__(self):

        return len(self.dataset)

    def __getitem__(self, idx):

        item = self.dataset[idx]

        image = item["Image"].convert("RGB")

        caption = item["Caption"]

        if self.train:
            image = train_transform(image)

        encoding = processor(

            text=caption,

            images=image,

            padding="max_length",

            truncation=True,

            max_length=77,

            return_tensors="pt"
        )

        return {

            "pixel_values":
                encoding["pixel_values"].squeeze(0),

            "input_ids":
                encoding["input_ids"].squeeze(0),

            "attention_mask":
                encoding["attention_mask"].squeeze(0),

            "label_B":
                torch.tensor(
                    item["Label_B"],
                    dtype=torch.long
                )
        }

# =========================================================
# DATALOADER SEEDING
# =========================================================
def seed_worker(worker_id):

    worker_seed = SEED + worker_id

    np.random.seed(worker_seed)

    random.seed(worker_seed)

g = torch.Generator()

g.manual_seed(SEED)

# =========================================================
# DATALOADERS
# =========================================================
BATCH_SIZE = 32

train_loader = DataLoader(
    MultiModalDataset(train_ds, train=True),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    worker_init_fn=seed_worker,
    generator=g
)

val_loader = DataLoader(
    MultiModalDataset(val_ds),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    worker_init_fn=seed_worker,
    generator=g
)

test_loader = DataLoader(
    MultiModalDataset(test_ds),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    worker_init_fn=seed_worker,
    generator=g
)

# =========================================================
# MODEL
# =========================================================
class CleanerMultiModalCLIP(nn.Module):

    def __init__(self):

        super().__init__()

        self.clip = CLIPModel.from_pretrained(
            "openai/clip-vit-base-patch32"
        )

        hidden_dim = self.clip.config.projection_dim

        # =================================================
        # FREEZE CLIP
        # =================================================
        for param in self.clip.parameters():
            param.requires_grad = False

        fusion_dim = hidden_dim * 2

        self.fusion = nn.Sequential(

            nn.Linear(fusion_dim, 256),

            nn.LayerNorm(256),

            nn.GELU(),

            nn.Dropout(0.5),

            nn.Linear(256, 128),

            nn.LayerNorm(128),

            nn.GELU(),

            nn.Dropout(0.5)
        )

        # =================================================
        # SINGLE 6-CLASS HEAD
        # =================================================
        self.classifier = nn.Linear(128, 6)

    def forward(
        self,
        pixel_values,
        input_ids,
        attention_mask
    ):

        with torch.no_grad():

            outputs = self.clip(

                pixel_values=pixel_values,

                input_ids=input_ids,

                attention_mask=attention_mask
            )

            image_feat = outputs.image_embeds

            text_feat = outputs.text_embeds

        fusion = torch.cat([

            image_feat,

            text_feat

        ], dim=1)

        fused = self.fusion(fusion)

        logits = self.classifier(fused)

        return logits

# =========================================================
# MODEL
# =========================================================
model = CleanerMultiModalCLIP().to(device)

# =========================================================
# LOSS
# =========================================================
criterion = nn.CrossEntropyLoss(
    label_smoothing=0.1
)

# =========================================================
# OPTIMIZER
# =========================================================
optimizer = torch.optim.AdamW(

    model.parameters(),

    lr=5e-6,

    weight_decay=1e-3
)

# =========================================================
# HISTORY
# =========================================================
train_losses = []

val_losses = []

val_accuracies = []

val_f1s = []

# =========================================================
# TRAINING
# =========================================================
best_score = 0

EPOCHS = 25

for epoch in range(EPOCHS):

    print(f"\n🔥 Epoch {epoch+1}/{EPOCHS}")

    model.train()

    total_loss = 0

    for batch in tqdm(train_loader):

        pixel_values = batch["pixel_values"].to(device)

        input_ids = batch["input_ids"].to(device)

        attention_mask = batch["attention_mask"].to(device)

        labels = batch["label_B"].to(device)

        optimizer.zero_grad()

        outputs = model(

            pixel_values,

            input_ids,

            attention_mask
        )

        loss = criterion(outputs, labels)

        loss.backward()

        torch.nn.utils.clip_grad_norm_(
            model.parameters(),
            1.0
        )

        optimizer.step()

        total_loss += loss.item()

    avg_train_loss = total_loss / len(train_loader)

    train_losses.append(avg_train_loss)

    print(f"Train Loss: {avg_train_loss:.4f}")

    # =====================================================
    # VALIDATION
    # =====================================================
    model.eval()

    preds = []

    targets = []

    val_loss = 0

    with torch.no_grad():

        for batch in val_loader:

            pixel_values = batch["pixel_values"].to(device)

            input_ids = batch["input_ids"].to(device)

            attention_mask = batch["attention_mask"].to(device)

            labels = batch["label_B"].to(device)

            outputs = model(

                pixel_values,

                input_ids,

                attention_mask
            )

            loss = criterion(outputs, labels)

            val_loss += loss.item()

            predictions = torch.argmax(outputs, dim=1)

            preds.extend(predictions.cpu().numpy())

            targets.extend(labels.cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)

    acc = accuracy_score(targets, preds)

    f1 = f1_score(
        targets,
        preds,
        average="weighted"
    )

    val_losses.append(avg_val_loss)

    val_accuracies.append(acc)

    val_f1s.append(f1)

    print("Validation Loss:", avg_val_loss)

    print("Validation Accuracy:", acc)

    print("Validation F1:", f1)

    # =====================================================
    # SAVE BEST MODEL
    # =====================================================
    if acc > best_score:

        best_score = acc

        torch.save({

            'epoch': epoch,

            'model_state_dict': model.state_dict(),

            'optimizer_state_dict': optimizer.state_dict(),

            'best_score': best_score

        }, "/content/drive/MyDrive/best_multimodal_clip_6class.pt")

        print("💾 Best model saved to Google Drive")

# =========================================================
# FINAL TEST
# =========================================================
print("\n🚀 FINAL TESTING")

checkpoint = torch.load(
    "/content/drive/MyDrive/best_multimodal_clip_6class.pt",
    map_location=device
)

model.load_state_dict(
    checkpoint['model_state_dict']
)

optimizer.load_state_dict(
    checkpoint['optimizer_state_dict']
)

print("✅ Best checkpoint loaded")

model.eval()

preds = []

targets = []

all_probs = []

test_loss = 0

with torch.no_grad():

    for batch in tqdm(test_loader):

        pixel_values = batch["pixel_values"].to(device)

        input_ids = batch["input_ids"].to(device)

        attention_mask = batch["attention_mask"].to(device)

        labels = batch["label_B"].to(device)

        outputs = model(

            pixel_values,

            input_ids,

            attention_mask
        )

        probabilities = torch.softmax(outputs, dim=1)

        all_probs.extend(
            probabilities.cpu().numpy()
        )

        loss = criterion(outputs, labels)

        test_loss += loss.item()

        predictions = torch.argmax(outputs, dim=1)

        preds.extend(predictions.cpu().numpy())

        targets.extend(labels.cpu().numpy())

# =========================================================
# TASK B RESULTS
# =========================================================
avg_test_loss = test_loss / len(test_loader)

acc = accuracy_score(targets, preds)

f1 = f1_score(
    targets,
    preds,
    average="weighted"
)

print("\nFINAL TASK B RESULTS")

print("Test Loss:", avg_test_loss)

print("Task B Accuracy:", acc)

print("Task B F1 Score:", f1)

print(
    classification_report(
        targets,
        preds
    )
)

# =========================================================
# TASK B CONFUSION MATRIX
# =========================================================
cm = confusion_matrix(
    targets,
    preds
)

plt.figure(figsize=(10,8))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.xlabel("Predicted")

plt.ylabel("True")

plt.title("Task B Confusion Matrix")

plt.show()

# =========================================================
# TRAIN VS VALIDATION LOSS
# =========================================================
plt.figure(figsize=(8,5))

plt.plot(
    range(1, len(train_losses)+1),
    train_losses,
    marker='o',
    linewidth=2,
    label='Train Loss'
)

plt.plot(
    range(1, len(val_losses)+1),
    val_losses,
    marker='o',
    linewidth=2,
    label='Validation Loss'
)

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.title("Training vs Validation Loss")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# VALIDATION ACCURACY GRAPH
# =========================================================
plt.figure(figsize=(8,5))

plt.plot(
    range(1, len(val_accuracies)+1),
    val_accuracies,
    marker='o',
    linewidth=2,
    label='Validation Accuracy'
)

plt.xlabel("Epoch")

plt.ylabel("Accuracy")

plt.title("Validation Accuracy")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# VALIDATION F1 GRAPH
# =========================================================
plt.figure(figsize=(8,5))

plt.plot(
    range(1, len(val_f1s)+1),
    val_f1s,
    marker='o',
    linewidth=2,
    label='Validation F1'
)

plt.xlabel("Epoch")

plt.ylabel("F1 Score")

plt.title("Validation F1 Score")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# TASK B PRECISION / RECALL / F1 GRAPH
# =========================================================
task_b_report = classification_report(
    targets,
    preds,
    output_dict=True
)

task_b_classes = ['0', '1', '2', '3', '4', '5']

task_b_precision = [
    task_b_report[c]["precision"]
    for c in task_b_classes
]

task_b_recall = [
    task_b_report[c]["recall"]
    for c in task_b_classes
]

task_b_f1_values = [
    task_b_report[c]["f1-score"]
    for c in task_b_classes
]

x = np.arange(len(task_b_classes))

width = 0.25

plt.figure(figsize=(12,6))

plt.bar(
    x - width,
    task_b_precision,
    width,
    label='Precision'
)

plt.bar(
    x,
    task_b_recall,
    width,
    label='Recall'
)

plt.bar(
    x + width,
    task_b_f1_values,
    width,
    label='F1'
)

plt.xticks(x, task_b_classes)

plt.xlabel("Class")

plt.ylabel("Score")

plt.title("Task B Precision / Recall / F1")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# TASK B ROC CURVES
# =========================================================
targets_bin = label_binarize(
    targets,
    classes=[0,1,2,3,4,5]
)

all_probs = np.array(all_probs)

fpr = dict()

tpr = dict()

roc_auc = dict()

for i in range(6):

    fpr[i], tpr[i], _ = roc_curve(
        targets_bin[:, i],
        all_probs[:, i]
    )

    roc_auc[i] = auc(
        fpr[i],
        tpr[i]
    )

plt.figure(figsize=(10,8))

for i in range(6):

    plt.plot(
        fpr[i],
        tpr[i],
        linewidth=2,
        label=f'Class {i} AUC = {roc_auc[i]:.3f}'
    )

plt.plot(
    [0,1],
    [0,1],
    linestyle='--'
)

plt.xlabel("False Positive Rate")

plt.ylabel("True Positive Rate")

plt.title("Task B ROC Curves")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# TASK B PR CURVES
# =========================================================
precision_dict = dict()

recall_dict = dict()

ap_dict = dict()

for i in range(6):

    precision_dict[i], recall_dict[i], _ = precision_recall_curve(

        targets_bin[:, i],

        all_probs[:, i]
    )

    ap_dict[i] = average_precision_score(

        targets_bin[:, i],

        all_probs[:, i]
    )

plt.figure(figsize=(10,8))

for i in range(6):

    plt.plot(

        recall_dict[i],

        precision_dict[i],

        linewidth=2,

        label=f'Class {i} AP = {ap_dict[i]:.3f}'
    )

plt.xlabel("Recall")

plt.ylabel("Precision")

plt.title("Task B Precision-Recall Curves")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# TASK A RESULTS
# =========================================================
binary_targets = [0 if x == 0 else 1 for x in targets]

binary_preds = [0 if x == 0 else 1 for x in preds]

task_a_acc = accuracy_score(
    binary_targets,
    binary_preds
)

task_a_f1 = f1_score(
    binary_targets,
    binary_preds,
    average="weighted"
)

print("\n============================")

print("TASK A RESULTS")

print("============================")

print("Task A Accuracy:", task_a_acc)

print("Task A F1 Score:", task_a_f1)

print(
    classification_report(
        binary_targets,
        binary_preds,
        target_names=["Real", "Fake"]
    )
)

# =========================================================
# TASK A CONFUSION MATRIX
# =========================================================
task_a_cm = confusion_matrix(
    binary_targets,
    binary_preds
)

plt.figure(figsize=(6,5))

sns.heatmap(
    task_a_cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.xlabel("Predicted")

plt.ylabel("True")

plt.title("Task A Confusion Matrix")

plt.show()

# =========================================================
# TASK A PRECISION / RECALL / F1 GRAPH
# =========================================================
task_a_report = classification_report(
    binary_targets,
    binary_preds,
    target_names=["Real", "Fake"],
    output_dict=True
)

task_a_classes = ["Real", "Fake"]

task_a_precision = [
    task_a_report[c]["precision"]
    for c in task_a_classes
]

task_a_recall = [
    task_a_report[c]["recall"]
    for c in task_a_classes
]

task_a_f1_values = [
    task_a_report[c]["f1-score"]
    for c in task_a_classes
]

x = np.arange(len(task_a_classes))

width = 0.25

plt.figure(figsize=(8,5))

plt.bar(
    x - width,
    task_a_precision,
    width,
    label='Precision'
)

plt.bar(
    x,
    task_a_recall,
    width,
    label='Recall'
)

plt.bar(
    x + width,
    task_a_f1_values,
    width,
    label='F1'
)

plt.xticks(x, task_a_classes)

plt.xlabel("Class")

plt.ylabel("Score")

plt.title("Task A Precision / Recall / F1")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# TASK A ROC CURVE
# =========================================================
binary_probs = 1 - all_probs[:,0]

fpr, tpr, _ = roc_curve(
    binary_targets,
    binary_probs
)

roc_auc = auc(
    fpr,
    tpr
)

plt.figure(figsize=(7,6))

plt.plot(
    fpr,
    tpr,
    linewidth=2,
    label=f'AUC = {roc_auc:.3f}'
)

plt.plot(
    [0,1],
    [0,1],
    linestyle='--'
)

plt.xlabel("False Positive Rate")

plt.ylabel("True Positive Rate")

plt.title("Task A ROC Curve")

plt.legend()

plt.grid(True)

plt.show()

# =========================================================
# TASK A PR CURVE
# =========================================================
precision_curve, recall_curve, _ = precision_recall_curve(

    binary_targets,

    binary_probs
)

ap_score = average_precision_score(

    binary_targets,

    binary_probs
)

plt.figure(figsize=(7,6))

plt.plot(

    recall_curve,

    precision_curve,

    linewidth=2,

    label=f'AP = {ap_score:.3f}'
)

plt.xlabel("Recall")

plt.ylabel("Precision")

plt.title("Task A Precision-Recall Curve")

plt.legend()

plt.grid(True)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🚀 Device: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 🔥 Epoch 1/25
# 100%|██████████| 1313/1313 [05:33<00:00,  3.94it/s]
# Train Loss: 1.8391
# Validation Loss: 1.666454943359321
# Validation Accuracy: 0.39166666666666666
# Validation F1: 0.39201622719144263
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 2/25
# 100%|██████████| 1313/1313 [05:36<00:00,  3.90it/s]
# Train Loss: 1.7345
# Validation Loss: 1.5143930649926476
# Validation Accuracy: 0.5161111111111111
# Validation F1: 0.4938268202653571
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 3/25
# 100%|██████████| 1313/1313 [05:35<00:00,  3.91it/s]
# Train Loss: 1.6239
# Validation Loss: 1.3772199965537864
# Validation Accuracy: 0.5597777777777778
# Validation F1: 0.5324890876826418
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 4/25
# 100%|██████████| 1313/1313 [05:34<00:00,  3.92it/s]
# Train Loss: 1.5192
# Validation Loss: 1.2786883842860552
# Validation Accuracy: 0.5945555555555555
# Validation F1: 0.5647187707520672
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 5/25
# 100%|██████████| 1313/1313 [05:32<00:00,  3.95it/s]
# Train Loss: 1.4358
# Validation Loss: 1.1992972662262882
# Validation Accuracy: 0.6304444444444445
# Validation F1: 0.6021501868114929
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 6/25
# 100%|██████████| 1313/1313 [05:35<00:00,  3.92it/s]
# Train Loss: 1.3703
# Validation Loss: 1.1421743388294328
# Validation Accuracy: 0.6477777777777778
# Validation F1: 0.6211512686826838
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 7/25
# 100%|██████████| 1313/1313 [05:32<00:00,  3.95it/s]
# Train Loss: 1.3153
# Validation Loss: 1.0917897304744586
# Validation Accuracy: 0.6745555555555556
# Validation F1: 0.6487587514459139
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 8/25
# 100%|██████████| 1313/1313 [05:34<00:00,  3.93it/s]
# Train Loss: 1.2660
# Validation Loss: 1.0519828098885557
# Validation Accuracy: 0.6878888888888889
# Validation F1: 0.6637828176286656
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 9/25
# 100%|██████████| 1313/1313 [05:33<00:00,  3.93it/s]
# Train Loss: 1.2221
# Validation Loss: 1.0138875366525446
# Validation Accuracy: 0.7087777777777777
# Validation F1: 0.6870397203553628
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 10/25
# 100%|██████████| 1313/1313 [05:34<00:00,  3.92it/s]
# Train Loss: 1.1890
# Validation Loss: 0.9836516872788152
# Validation Accuracy: 0.7224444444444444
# Validation F1: 0.7005052578493932
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 11/25
# 100%|██████████| 1313/1313 [05:37<00:00,  3.89it/s]
# Train Loss: 1.1614
# Validation Loss: 0.9640216328573565
# Validation Accuracy: 0.731
# Validation F1: 0.7120875567862823
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 12/25
# 100%|██████████| 1313/1313 [05:44<00:00,  3.82it/s]
# Train Loss: 1.1271
# Validation Loss: 0.9379673927811021
# Validation Accuracy: 0.7433333333333333
# Validation F1: 0.7256741104850525
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 13/25
# 100%|██████████| 1313/1313 [05:45<00:00,  3.80it/s]
# Train Loss: 1.1077
# Validation Loss: 0.9181355576143198
# Validation Accuracy: 0.7527777777777778
# Validation F1: 0.7365325574282147
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 14/25
# 100%|██████████| 1313/1313 [05:48<00:00,  3.77it/s]
# Train Loss: 1.0851
# Validation Loss: 0.9020672736438453
# Validation Accuracy: 0.7585555555555555
# Validation F1: 0.7432171009732512
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 15/25
# 100%|██████████| 1313/1313 [05:49<00:00,  3.75it/s]
# Train Loss: 1.0632
# Validation Loss: 0.8882012157998187
# Validation Accuracy: 0.7648888888888888
# Validation F1: 0.7512206910888004
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 16/25
# 100%|██████████| 1313/1313 [05:48<00:00,  3.77it/s]
# Train Loss: 1.0455
# Validation Loss: 0.8761442804590185
# Validation Accuracy: 0.7734444444444445
# Validation F1: 0.7631220183979563
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 17/25
# 100%|██████████| 1313/1313 [05:49<00:00,  3.75it/s]
# Train Loss: 1.0250
# Validation Loss: 0.8632653799462826
# Validation Accuracy: 0.7845555555555556
# Validation F1: 0.7757209534975791
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 18/25
# 100%|██████████| 1313/1313 [05:52<00:00,  3.73it/s]
# Train Loss: 1.0120
# Validation Loss: 0.8462726953604542
# Validation Accuracy: 0.7902222222222223
# Validation F1: 0.7827313440368932
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 19/25
# 100%|██████████| 1313/1313 [05:55<00:00,  3.70it/s]
# Train Loss: 1.0017
# Validation Loss: 0.8356213299095208
# Validation Accuracy: 0.7981111111111111
# Validation F1: 0.79221153212867
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 20/25
# 100%|██████████| 1313/1313 [05:54<00:00,  3.71it/s]
# Train Loss: 0.9857
# Validation Loss: 0.8263074083531157
# Validation Accuracy: 0.8036666666666666
# Validation F1: 0.79768421210402
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 21/25
# 100%|██████████| 1313/1313 [05:53<00:00,  3.71it/s]
# Train Loss: 0.9740
# Validation Loss: 0.8172002665117277
# Validation Accuracy: 0.8092222222222222
# Validation F1: 0.8049954688537556
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 22/25
# 100%|██████████| 1313/1313 [05:52<00:00,  3.73it/s]
# Train Loss: 0.9603
# Validation Loss: 0.8035505202645106
# Validation Accuracy: 0.8198888888888889
# Validation F1: 0.8159476697550158
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 23/25
# 100%|██████████| 1313/1313 [05:51<00:00,  3.74it/s]
# Train Loss: 0.9532
# Validation Loss: 0.7982511632408656
# Validation Accuracy: 0.8236666666666667
# Validation F1: 0.8209844948739402
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 24/25
# 100%|██████████| 1313/1313 [05:51<00:00,  3.74it/s]
# Train Loss: 0.9452
# Validation Loss: 0.7900767465855213
# Validation Accuracy: 0.826
# Validation F1: 0.8228562324833181
# 💾 Best model saved to Google Drive
#
# 🔥 Epoch 25/25
# 100%|██████████| 1313/1313 [05:49<00:00,  3.75it/s]
# Train Loss: 0.9331
# Validation Loss: 0.7781000974330496
# Validation Accuracy: 0.8362222222222222
# Validation F1: 0.8339248997074563
# 💾 Best model saved to Google Drive
#
# 🚀 FINAL TESTING
# ✅ Best checkpoint loaded
# 100%|██████████| 1407/1407 [07:01<00:00,  3.34it/s]
# FINAL TASK B RESULTS
# Test Loss: 0.8941479063067947
# Task B Accuracy: 0.7764222222222222
# Task B F1 Score: 0.7721550700906816
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      7500
#            1       0.76      0.62      0.68      7500
#            2       0.85      0.76      0.80      7500
#            3       0.70      0.82      0.75      7500
#            4       0.70      0.99      0.82      7500
#            5       0.93      0.60      0.73      7500
#
#     accuracy                           0.78     45000
#    macro avg       0.79      0.78      0.77     45000
# weighted avg       0.79      0.78      0.77     45000
# ============================
# TASK A RESULTS
# ============================
# Task A Accuracy: 0.9473777777777778
# Task A F1 Score: 0.9480008649946458
#               precision    recall  f1-score   support
#
#         Real       0.82      0.87      0.85      7500
#         Fake       0.97      0.96      0.97     37500
#
#     accuracy                           0.95     45000
#    macro avg       0.90      0.92      0.91     45000
# weighted avg       0.95      0.95      0.95     45000
